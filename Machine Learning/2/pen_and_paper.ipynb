# %% [markdown]
# # Pen-and-paper

# %%
import numpy as np, pandas as pd
from sklearn.model_selection import LeaveOneOut
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import recall_score
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# ### Exercício 1 Data

# %%
data = {'y1': [0,1,0,0,1,1,0,1],
        'y2': [0,1,1,0,0,0,1,1],
        'class': [0,0,0,0,1,1,1,1]}

df = pd.DataFrame(data)
X = df.loc[:, df.columns != 'class']
y = df.loc[:, 'class']

# %% [markdown]
# ### Exercício 1

# %%
loo = LeaveOneOut()
kNN = KNeighborsClassifier(weights='uniform', n_neighbors=5, metric='hamming')

y_pred = []
for train_index, test_index in loo.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    kNN.fit(X_train, y_train)
    y_pred += [kNN.predict(X_test)[0]]

recall = recall_score(y, y_pred)
print(recall)
# Out:
# 0.25

# %% [markdown]
# ### Exercício 2 Data

# %%
data = {'y1': [0, 1, 0, 0, 1, 1, 0, 1, 1],
        'y2': [0, 1, 1, 0, 0, 0, 1, 1, 0],
        'y3': [1.2, 0.8, 0.5, 0.9, 1, 0.9, 1.2, 0.8, 0.8],
        'class': [0, 0, 0, 0, 1, 1, 1, 1, 0]}

df = pd.DataFrame(data)
X_train = df.loc[:, df.columns != 'class']
y_train = df.loc[:, 'class']

# %% [markdown]
# ### Exercício 2

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ### Exercício 3 Data

# %%
data = {'y1': [0, 1, 1],
        'y2': [1, 1, 0],
        'y3': [0.8, 1, 0.9]}

X_test = pd.DataFrame(data)
y_test = np.array([0, 0, 1])

# %% [markdown]
# ### Exercício 3

# %%
y_pred = gnb.predict(X_test)

print('y_test:', y_test)
print('y_pred:', y_pred)
# Out:
# y_test: [0 0 1]
# y_pred: [0 1 1]
